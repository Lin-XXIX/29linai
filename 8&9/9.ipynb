# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as se
sp=pd.read_csv(r"C:\Users\aniket khankar\Downloads\Adsbda\8\titanic1.csv")

# %%
from seaborn import load_dataset
tips=load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sp.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
se.countplot(x='Survived',data=sp)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sp["Sex"].value_counts().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(sp["Age"],bins=20)
plt.show()

# %%
se.distplot(sp["Age"])
plt.show()
# Out:
# C:\Users\aniket khankar\AppData\Local\Temp\ipykernel_15756\3556467990.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   se.distplot(sp["Age"])

# %%
plt.scatter(tips["total_bill"],tips["tip"])

# %%
se.scatterplot(data=tips,x="total_bill",y="tip",hue=tips["sex"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
se.scatterplot(data=tips,x="total_bill",y="tip",hue=tips["sex"],style=tips["smoker"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
se.barplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.barplot(x="Age",y="Fare",data=sp,hue=sp["Sex"])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
se.boxplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.boxplot(x="Sex",y="Age",data=sp,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.distplot(sp[sp["Survived"]==0]["Age"],hist=False,color="blue")
se.distplot(sp[sp["Survived"]==1]["Age"],hist=False,color="orange")
plt.show()
# Out:
# C:\Users\aniket khankar\AppData\Local\Temp\ipykernel_15756\1493518275.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   se.distplot(sp[sp["Survived"]==0]["Age"],hist=False,color="blue")
# C:\Users\aniket khankar\AppData\Local\Temp\ipykernel_15756\1493518275.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
pd.crosstab(sp["Sex"],sp["Survived"])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
se.heatmap(pd.crosstab(sp["Sex"],sp["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
se.clustermap(pd.crosstab(sp["Parch"],sp["Survived"]))
