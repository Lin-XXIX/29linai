# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as se
sp=pd.read_csv(r"C:\Users\aniket khankar\Downloads\Adsbda\8\titanic1.csv")

# %%
sp.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
se.distplot(sp["Fare"])
# Out:
# C:\Users\aniket khankar\AppData\Local\Temp\ipykernel_24216\347951050.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   se.distplot(sp["Fare"])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
se.distplot(sp["Fare"],bins=10)
# Out:
# C:\Users\aniket khankar\AppData\Local\Temp\ipykernel_24216\808665739.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   se.distplot(sp["Fare"],bins=10)
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
se.jointplot(x="Age",y="Fare",data=sp)

# %%
se.jointplot(x="Age",y="Fare",data=sp,kind='hex')

# %%
se.pairplot(sp)

# %%
sp=sp.dropna()

# %%
se.pairplot(sp,hue='Sex')

# %%
se.rugplot(sp["Fare"])
# Out:
# <Axes: xlabel='Fare'>

# %%
se.barplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.barplot(x="Sex",y="Age",data=sp,estimator=np.std)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.countplot(x="Sex",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
se.boxplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.boxplot(x="Sex",y="Age",data=sp,hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.violinplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.violinplot(x="Sex",y="Age",data=sp,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.violinplot(x="Sex",y="Age",data=sp,hue="Survived",split="True")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.stripplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.stripplot(x="Sex",y="Age",data=sp,jitter=True)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.stripplot(x="Sex",y="Age",data=sp,jitter=True,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.swarmplot(x="Sex",y="Age",data=sp)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.swarmplot(x="Sex",y="Age",data=sp,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
se.violinplot(x="Sex",y="Age",data=sp)
se.swarmplot(x="Sex",y="Age",data=sp,color="red")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
